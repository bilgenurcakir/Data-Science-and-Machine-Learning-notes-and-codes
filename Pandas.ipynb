# %%
import numpy as np
import pandas as pd

# %%
# Series

# %%
grades={"Atil":40, "Bilge":90, "Lars":30}

# %%
pd.Series(grades)
# Out:
# Atil     40
# Bilge    90
# Lars     30
# dtype: int64

# %%
names=["Atil","Bilge","Lars"]
grades=[40,90,30]
pd.Series(names)
# Out:
# 0     Atil
# 1    Bilge
# 2     Lars
# dtype: object

# %%
pd.Series(grades)
# Out:
# 0    40
# 1    90
# 2    30
# dtype: int64

# %%
pd.Series(grades,names)
# Out:
# Atil     40
# Bilge    90
# Lars     30
# dtype: int64

# %%
pd.Series(names,grades)
# Out:
# 40     Atil
# 90    Bilge
# 30     Lars
# dtype: object

# %%
pd.Series( data=grades,index=names)
# Out:
# Atil     40
# Bilge    90
# Lars     30
# dtype: int64

# %%
#with numpy

# %%
numpy_array=np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#aritmethic

# %%
result=pd.Series(data=[10,5,100], index=["Atil","Bilge","Lars"])

# %%
result2=pd.Series(data=[20,50,10], index=["Atil","Bilge","Lars"])

# %%
result
# Out:
# Atil      10
# Bilge      5
# Lars     100
# dtype: int64

# %%
result2
# Out:
# Atil     20
# Bilge    50
# Lars     10
# dtype: int64

# %%
final=result+result2
final
# Out:
# Atil      30
# Bilge     55
# Lars     110
# dtype: int64

# %%
series1=pd.Series([20,30,40,50],["a","b","c","d"])
series2=pd.Series([10,5,3,1],["a","c","f","g"])

series1+series2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64

# %%
# Dataframe

# %%
data=np.random.randn(4,3)
data
# Out:
# array([[ 0.98236746, -1.67189884,  0.20749687],
#        [-0.7248522 ,  1.51707186,  1.94950382],
#        [ 1.33632312,  0.51400247,  0.59741126],
#        [ 0.036212  ,  0.32646632,  1.48481475]])

# %%
data_frame=pd.DataFrame(data)
data_frame
# Out:
#           0         1         2
# 0  0.982367 -1.671899  0.207497
# 1 -0.724852  1.517072  1.949504
# 2  1.336323  0.514002  0.597411
# 3  0.036212  0.326466  1.484815

# %%
 type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame[0]
# Out:
# 0    0.982367
# 1   -0.724852
# 2    1.336323
# 3    0.036212
# Name: 0, dtype: float64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df=pd.DataFrame(data,index=["bilge","zumra","hatice","akın"],columns=["salary","age","seniority"])
new_df
# Out:
#           salary       age  seniority
# bilge   0.982367 -1.671899   0.207497
# zumra  -0.724852  1.517072   1.949504
# hatice  1.336323  0.514002   0.597411
# akın    0.036212  0.326466   1.484815

# %%
new_df["age"]
# Out:
# bilge    -1.671899
# zumra     1.517072
# hatice    0.514002
# akın      0.326466
# Name: age, dtype: float64

# %%
new_df[["age","salary"]]
# Out:
#              age    salary
# bilge  -1.671899  0.982367
# zumra   1.517072 -0.724852
# hatice  0.514002  1.336323
# akın    0.326466  0.036212

# %%
new_df.loc["bilge"] #rowdan getirmek için
# Out:
# salary       0.982367
# age         -1.671899
# seniority    0.207497
# Name: bilge, dtype: float64

# %%
new_df.iloc[0] # 0. rowdakini getir
# Out:
# salary       0.982367
# age         -1.671899
# seniority    0.207497
# Name: bilge, dtype: float64

# %%
new_df.iloc[:,1] #:  tüm satırlar için  1. kolonu al
# Out:
# bilge    -1.671899
# zumra     1.517072
# hatice    0.514002
# akın      0.326466
# Name: age, dtype: float64

# %%
#data manipulation

# %%
new_df["extra"]=10

# %%
new_df
# Out:
#           salary       age  seniority  extra
# bilge   0.982367 -1.671899   0.207497     10
# zumra  -0.724852  1.517072   1.949504     10
# hatice  1.336323  0.514002   0.597411     10
# akın    0.036212  0.326466   1.484815     10

# %%
new_df.drop("extra", axis=1, inplace=True) 
# extra sutununu sil 
#( axis:1 sutun demek axis:0 satır demek)
# inplace: dataframe'in kendisinde de değiştir

# %%
new_df.loc["zumra"]
# Out:
# salary      -0.724852
# age          1.517072
# seniority    1.949504
# Name: zumra, dtype: float64

# %%
new_df.loc["zumra"]["salary"]
# Out:
# -0.7248522004163807

# %%
new_df.loc["zumra","salary"]
# Out:
# -0.7248522004163807

# %%
new_df.loc["zumra","salary"]=100
new_df
# Out:
#             salary       age  seniority
# bilge     0.982367 -1.671899   0.207497
# zumra   100.000000  1.517072   1.949504
# hatice    1.336323  0.514002   0.597411
# akın      0.036212  0.326466   1.484815

# %%
bool_frame=new_df >0
bool_frame
# Out:
#         salary    age  seniority
# bilge     True  False       True
# zumra     True   True       True
# hatice    True   True       True
# akın      True   True       True

# %%
new_df[new_df>0]
# Out:
#             salary       age  seniority
# bilge     0.982367       NaN   0.207497
# zumra   100.000000  1.517072   1.949504
# hatice    1.336323  0.514002   0.597411
# akın      0.036212  0.326466   1.484815

# %%
new_df[new_df["age"]>0]
# Out:
#             salary       age  seniority
# zumra   100.000000  1.517072   1.949504
# hatice    1.336323  0.514002   0.597411
# akın      0.036212  0.326466   1.484815

# %%
#index

# %%
 reset_frame=new_df.reset_index()
reset_frame
# Out:
#     index      salary       age  seniority
# 0   bilge    0.982367 -1.671899   0.207497
# 1   zumra  100.000000  1.517072   1.949504
# 2  hatice    1.336323  0.514002   0.597411
# 3    akın    0.036212  0.326466   1.484815

# %%
reset_frame.loc[0]
# Out:
# index           bilge
# salary       0.982367
# age         -1.671899
# seniority    0.207497
# Name: 0, dtype: object

# %%
new_indices=["ati","zey","bil","meh"]
new_df["NewIndex"]=new_indices
new_df
# Out:
#             salary       age  seniority NewIndex
# bilge     0.982367 -1.671899   0.207497      ati
# zumra   100.000000  1.517072   1.949504      zey
# hatice    1.336323  0.514002   0.597411      bil
# akın      0.036212  0.326466   1.484815      meh

# %%
new_df.set_index("NewIndex",inplace=True)
new_df
# Out:
#               salary       age  seniority
# NewIndex
# ati         0.982367 -1.671899   0.207497
# zey       100.000000  1.517072   1.949504
# bil         1.336323  0.514002   0.597411
# meh         0.036212  0.326466   1.484815

# %%
new_df.loc["ati"]
# Out:
# salary       0.982367
# age         -1.671899
# seniority    0.207497
# Name: ati, dtype: float64

# %%
#multi index

# %%
first_index=["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
inner_index=["Homer","bart","marge","cartman","kenny","kyle"]

# %%
zipped_index=list(zip(first_index,inner_index))
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'bart'),
#  ('Simpson', 'marge'),
#  ('South Park', 'cartman'),
#  ('South Park', 'kenny'),
#  ('South Park', 'kyle')]

# %%
zipped_index=pd.MultiIndex.from_tuples(zipped_index)
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'bart'),
#             (   'Simpson',   'marge'),
#             ('South Park', 'cartman'),
#             ('South Park',   'kenny'),
#             ('South Park',    'kyle')],
#            )

# %%
values=np.ones((6,2))

# %%
big_df=pd.DataFrame(values,index=zipped_index,columns=["age","salary"])
big_df
# Out:
#                     age  salary
# Simpson    Homer    1.0     1.0
#            bart     1.0     1.0
#            marge    1.0     1.0
# South Park cartman  1.0     1.0
#            kenny    1.0     1.0
#            kyle     1.0     1.0

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# age       1.0
# salary    1.0
# Name: Homer, dtype: float64

# %%
big_df["age"]
# Out:
# Simpson     Homer      1.0
#             bart       1.0
#             marge      1.0
# South Park  cartman    1.0
#             kenny      1.0
#             kyle       1.0
# Name: age, dtype: float64

# %%
# groupby

# %%
df=pd.read_csv("6-employee.csv")
df
# Out:
#    Department Employee  Salary  Experience           City
# 0   Marketing    Emp_1   53483           1       New York
# 1       Sales    Emp_2   78555           8         Austin
# 2     Finance    Emp_3   47159           3         Austin
# 3       Sales    Emp_4  110077           3  San Francisco
# 4       Sales    Emp_5   65920           1       New York
# 5          IT    Emp_6   97121          11        Chicago
# 6     Finance    Emp_7   99479           5        Chicago
# 7     Finance    Emp_8  119475          10       New York
# 8     Finance    Emp_9   49457           7        Chicago
# 9       Sales   Emp_10   96557          10        Chicago
# 10  Marketing   Emp_11  107189           9       New York
# 11    Finance   Emp_12  108953          12         Austin
# 12      Sales   Emp_13   82995           7       New York
# 13         IT   Emp_14   70757           9         Austin
# 14  Marketing   Emp_15   39692           8        Chicago
# ...

# %%
df.describe()
# Out:
#               Salary  Experience
# count      50.000000   50.000000
# mean    78344.500000    7.060000
# std     27817.603904    3.966235
# min     31016.000000    1.000000
# 25%     53687.250000    3.000000
# 50%     78769.500000    7.000000
# 75%    100778.000000   10.000000
# max    119812.000000   14.000000

# %%
df["Salary"].mean()
# Out:
# 78344.5

# %%
df[["Salary","Experience"]].mean()
# Out:
# Salary        78344.50
# Experience        7.06
# dtype: float64

# %%
df.count()
# Out:
# Department    50
# Employee      50
# Salary        50
# Experience    50
# City          50
# dtype: int64

# %%
 df[df["Experience"]>6].count() #tecrubesi 6 yıldan fazla olan 30 kişi var.
# Out:
# Department    30
# Employee      30
# Salary        30
# Experience    30
# City          30
# dtype: int64

# %%
df_grouped=df.groupby("Department") # departmanlara göre grupla
df_grouped.count()
# Out:
#             Employee  Salary  Experience  City
# Department
# Finance           10      10          10    10
# HR                 7       7           7     7
# IT                10      10          10    10
# Marketing         13      13          13    13
# Sales             10      10          10    10

# %%
df_grouped.describe()
# Out:
#            Salary                                                          \
#             count          mean           std      min       25%      50%
# Department
# Finance      10.0  90552.700000  27228.231832  47159.0  73222.00  96591.5
# HR            7.0  76182.571429  31647.523983  31016.0  55114.50  78984.0
# IT           10.0  63381.600000  24272.881041  32568.0  39755.25  66681.5
# Marketing    13.0  79555.000000  28431.207129  39268.0  54300.00  70774.0
# Sales        10.0  81038.900000  26623.181534  38571.0  68987.50  80775.0
#
#                                 Experience                                \
#                   75%       max      count      mean       std  min  25%
# Department
# Finance     111836.75  119812.0       10.0  6.500000  3.566822  1.0  3.5
# HR           96630.00  119789.0        7.0  8.714286  4.572173  3.0  5.0
# IT           79850.00   97121.0       10.0  9.000000  4.163332  1.0  7.5
# ...

# %%
df_grouped["Salary"].mean()
# Out:
# Department
# Finance      90552.700000
# HR           76182.571429
# IT           63381.600000
# Marketing    79555.000000
# Sales        81038.900000
# Name: Salary, dtype: float64

# %%
df_city=df.groupby("City") #sehirlere göre grupla

# %%
df_city["Salary"].mean() # o şehrin ortalama maaşı
# Out:
# City
# Austin           81216.000000
# Chicago          76869.363636
# New York         70484.133333
# San Francisco    87144.727273
# Name: Salary, dtype: float64
